# %%
# Importing required libraries
import requests
import json

# %%
# Testing the Open-Meteo current weather API using Nepal's coordinates
lat, lon = country_coordinates["Nepal"] if "country_coordinates" in dir() else (28.3949, 84.1240)

url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": lat,
    "longitude": lon,
    "current_weather": True
}

response = requests.get(url, params=params)
data = response.json()

print(json.dumps(data, indent=2))
# Out:
# {
#   "latitude": 28.295254,
#   "longitude": 84.18368,
#   "generationtime_ms": 0.2053976058959961,
#   "utc_offset_seconds": 0,
#   "timezone": "GMT",
#   "timezone_abbreviation": "GMT",
#   "elevation": 1958.0,
#   "current_weather_units": {
#     "time": "iso8601",
#     "interval": "seconds",
#     "temperature": "\u00b0C",
#     "windspeed": "km/h",
#     "winddirection": "\u00b0",
#     "is_day": "",
#     "weathercode": "wmo code"
#   },
#   "current_weather": {
#     "time": "2026-07-06T03:30",
#     "interval": 900,
#     "temperature": 20.2,
#     "windspeed": 7.1,
#     "winddirection": 210,
#     "is_day": 1,
#     "weathercode": 51
#   }
# }

# %%
# Mapping Open-Meteo's WMO weather codes to human-readable conditions
weather_code_map = {
    0: "Clear sky",
    1: "Mainly clear",
    2: "Partly cloudy",
    3: "Overcast",
    45: "Fog",
    48: "Depositing rime fog",
    51: "Light drizzle",
    53: "Moderate drizzle",
    55: "Dense drizzle",
    61: "Slight rain",
    63: "Moderate rain",
    65: "Heavy rain",
    71: "Slight snow",
    73: "Moderate snow",
    75: "Heavy snow",
    80: "Slight rain showers",
    81: "Moderate rain showers",
    82: "Violent rain showers",
    95: "Thunderstorm",
    96: "Thunderstorm with slight hail",
    99: "Thunderstorm with heavy hail",
}

def get_weather_description(code):
    return weather_code_map.get(code, "Unknown")

# Testing it on Nepal's actual result
condition = get_weather_description(data["current_weather"]["weathercode"])
print("Current condition in Nepal:", condition)
# Out:
# Current condition in Nepal: Light drizzle

# %%
# A single reusable function: give it coordinates, get back clean current weather info
def get_current_weather(lat, lon):
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": lat,
        "longitude": lon,
        "current_weather": True
    }
    response = requests.get(url, params=params)
    data = response.json()

    current = data["current_weather"]
    return {
        "temperature": current["temperature"],
        "windspeed": current["windspeed"],
        "condition": get_weather_description(current["weathercode"]),
        "is_day": bool(current["is_day"])
    }

# Testing it
get_current_weather(lat, lon)
# Out:
# {'temperature': 20.4,
#  'windspeed': 5.8,
#  'condition': 'Light drizzle',
#  'is_day': True}

# %%
# Testing the new module works correctly
import sys
sys.path.append("../src/api")

from weather_client import get_current_weather
from country_lookup import load_country_coordinates, get_coordinates

coords = load_country_coordinates()
lat, lon = get_coordinates("Nepal", coords)
print(get_current_weather(lat, lon))
# Out:
# {'temperature': 15.9, 'windspeed': 7.1, 'condition': 'Moderate drizzle', 'is_day': True}
